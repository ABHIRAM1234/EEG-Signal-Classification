# %% [markdown]
# <a href="https://colab.research.google.com/github/Surya-Deepak/ECG-Signal-Classification/blob/main/EDA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Data = np.loadtxt(open(str('/content/filtered_signals.csv'), "rb"), delimiter=",", skiprows=1)
labels = Data[:, -1]
Data1 = Data[401, :-1] 
#normal
plt.title("Normal signal")
plt.plot(np.arange(4098), Data1)
plt.show()

# %%
Data2 = Data[402, :-1]
#seizure
plt.title("Seizure signal")
plt.plot(np.arange(4098), Data2)
plt.show()
