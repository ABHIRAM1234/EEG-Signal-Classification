# %% [markdown]
# Download and extract data

# %%
! wget -O A.zip http://epileptologie-bonn.de/cms/upload/workgroup/lehnertz/Z.zip
! wget -O B.zip http://epileptologie-bonn.de/cms/upload/workgroup/lehnertz/O.zip
! wget -O C.zip http://epileptologie-bonn.de/cms/upload/workgroup/lehnertz/N.zip
! wget -O D.zip http://epileptologie-bonn.de/cms/upload/workgroup/lehnertz/F.zip
! wget -O E.zip http://epileptologie-bonn.de/cms/upload/workgroup/lehnertz/S.zip
# Out:
# --2021-08-11 17:40:05--  http://epileptologie-bonn.de/cms/upload/workgroup/lehnertz/Z.zip
# Resolving epileptologie-bonn.de (epileptologie-bonn.de)... 83.169.36.208
# Connecting to epileptologie-bonn.de (epileptologie-bonn.de)|83.169.36.208|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 578047 (564K) [application/zip]
# Saving to: ‘A.zip’
#
# A.zip               100%[===================>] 564.50K   732KB/s    in 0.8s
#
# 2021-08-11 17:40:07 (732 KB/s) - ‘A.zip’ saved [578047/578047]
#
# --2021-08-11 17:40:07--  http://epileptologie-bonn.de/cms/upload/workgroup/lehnertz/O.zip
# Resolving epileptologie-bonn.de (epileptologie-bonn.de)... 83.169.36.208
# Connecting to epileptologie-bonn.de (epileptologie-bonn.de)|83.169.36.208|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625970 (611K) [application/zip]
# Saving to: ‘B.zip’
#
# B.zip               100%[===================>] 611.30K   787KB/s    in 0.8s
#
# 2021-08-11 17:40:08 (787 KB/s) - ‘B.zip’ saved [625970/625970]
#
# --2021-08-11 17:40:08--  http://epileptologie-bonn.de/cms/upload/workgroup/lehnertz/N.zip
# Resolving epileptologie-bonn.de (epileptologie-bonn.de)... 83.169.36.208
# Connecting to epileptologie-bonn.de (epileptologie-bonn.de)|83.169.36.208|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 574452 (561K) [application/zip]
# Saving to: ‘C.zip’
#
# C.zip               100%[===================>] 560.99K   726KB/s    in 0.8s
#
# 2021-08-11 17:40:09 (726 KB/s) - ‘C.zip’ saved [574452/574452]
#
# --2021-08-11 17:40:09--  http://epileptologie-bonn.de/cms/upload/workgroup/lehnertz/F.zip
# Resolving epileptologie-bonn.de (epileptologie-bonn.de)... 83.169.36.208
# Connecting to epileptologie-bonn.de (epileptologie-bonn.de)|83.169.36.208|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 582967 (569K) [application/zip]
# Saving to: ‘D.zip’
#
# D.zip               100%[===================>] 569.30K   620KB/s    in 0.9s
#
# 2021-08-11 17:40:10 (620 KB/s) - ‘D.zip’ saved [582967/582967]
#
# --2021-08-11 17:40:10--  http://epileptologie-bonn.de/cms/upload/workgroup/lehnertz/S.zip
# Resolving epileptologie-bonn.de (epileptologie-bonn.de)... 83.169.36.208
# Connecting to epileptologie-bonn.de (epileptologie-bonn.de)|83.169.36.208|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 764359 (746K) [application/zip]
# Saving to: ‘E.zip’
#
# E.zip               100%[===================>] 746.44K   950KB/s    in 0.8s
#
# 2021-08-11 17:40:11 (950 KB/s) - ‘E.zip’ saved [764359/764359]

# %%
! mkdir A B C D E

# %%
! unzip /content/A.zip -d A
! unzip /content/B.zip -d B
! unzip /content/C.zip -d C
! unzip /content/D.zip -d D
! unzip /content/E.zip -d E
! rm -rf /content/A.zip
! rm -rf /content/B.zip
! rm -rf /content/D.zip
! rm -rf /content/C.zip
! rm -rf /content/E.zip
# Out:
# Archive:  /content/A.zip
#   inflating: A/Z092.txt
#   inflating: A/Z002.txt
#   inflating: A/Z003.txt
#   inflating: A/Z004.txt
#   inflating: A/Z005.txt
#   inflating: A/Z006.txt
#   inflating: A/Z007.txt
#   inflating: A/Z008.txt
#   inflating: A/Z009.txt
#   inflating: A/Z010.txt
#   inflating: A/Z011.txt
#   inflating: A/Z012.txt
#   inflating: E/S056.txt
#   inflating: E/S055.txt
#   inflating: E/S054.txt
#   inflating: E/S053.txt
#   inflating: E/S052.txt
#   inflating: E/S051.txt
#   inflating: E/S050.txt
#   inflating: E/S049.txt
#   inflating: E/S048.txt
#   inflating: E/S047.txt
#   inflating: E/S046.txt
#   inflating: E/S045.txt
#   inflating: E/S044.txt
#   inflating: E/S043.txt
#   inflating: E/S042.txt
#   inflating: E/S041.txt
#   inflating: E/S040.txt
#   inflating: E/S039.txt
#   inflating: E/S038.txt
#   inflating: E/S037.txt
#   inflating: E/S036.txt
#   inflating: E/S035.txt
#   inflating: E/S034.txt
#   inflating: E/S033.txt
#   inflating: E/S032.txt
#   inflating: E/S031.txt
#   inflating: E/S030.txt
#   inflating: E/S029.txt
#   inflating: E/S028.txt
#   inflating: E/S027.txt
#   inflating: E/S026.txt
#   inflating: E/S025.txt
#   inflating: E/S024.txt
#   inflating: E/S023.txt
#   inflating: E/S022.txt
#   inflating: E/S021.txt
#   inflating: E/S020.txt
#   inflating: E/S019.txt
#   inflating: E/S018.txt
#   inflating: E/S017.txt
#   inflating: E/S016.txt
#   inflating: E/S015.txt
#   inflating: E/S014.txt
#   inflating: E/S013.txt
#   inflating: E/S012.txt
#   inflating: E/S100.txt
#   inflating: E/S010.txt
#   inflating: E/S009.txt
#   inflating: E/S008.txt
#   inflating: E/S007.txt
#   inflating: E/S006.txt
#   inflating: E/S005.txt
#   inflating: E/S004.txt
#   inflating: E/S003.txt
#   inflating: E/S002.txt
#   inflating: E/S001.txt

# %%
# !ls
# Out:
# A  B  C  D  E  sample_data

# %% [markdown]
# Load and preprocess data

# %%
import os

root = "/content/"
files = os.listdir()

A_path = os.path.join(root, [elem for elem in files if elem=='A'][0])
B_path = os.path.join(root, [elem for elem in files if elem=='B'][0])
C_path = os.path.join(root, [elem for elem in files if elem=='C'][0])
D_path = os.path.join(root, [elem for elem in files if elem=='D'][0])
E_path = os.path.join(root, [elem for elem in files if elem=='E'][0])

print(A_path)
print(B_path)
print(C_path)
print(D_path)
print(E_path)
# Out:
# /content/A
# /content/B
# /content/C
# /content/D
# /content/E

# %% [markdown]
# Load and Pre-Process

# %% [markdown]
# A

# %%
import numpy as np
A_files = [os.path.join(A_path, path) for path in os.listdir(A_path)]

A_signals = []

for signal in A_files:
  signal = np.loadtxt(signal)
  A_signals.append(signal)

A_signals = np.array(A_signals)

# %% [markdown]
# B

# %%
B_files = [os.path.join(B_path, path) for path in os.listdir(B_path)]

B_signals = []

for signal in B_files:
  signal = np.loadtxt(signal)
  B_signals.append(signal)

B_signals = np.array(B_signals)

# %% [markdown]
# C

# %%
C_files = [os.path.join(C_path, path) for path in os.listdir(C_path)]

C_signals = []


for signal in C_files:
  signal = np.loadtxt(signal)
  C_signals.append(signal)

C_signals = np.array(C_signals)

# %% [markdown]
# D

# %%
D_files = [os.path.join(D_path, path) for path in os.listdir(D_path)]

D_signals = []

for signal in D_files:
  signal = np.loadtxt(signal)
  D_signals.append(signal)

D_signals = np.array(D_signals)

# %% [markdown]
# E

# %%
E_files = [os.path.join(E_path, path) for path in os.listdir(E_path)]

E_signals = []

for signal in E_files:
  signal = np.loadtxt(signal)
  E_signals.append(signal)

E_signals = np.array(E_signals)

# %%
print(A_signals.shape)
print(B_signals.shape)
print(C_signals.shape)
print(D_signals.shape)
print(E_signals.shape)
# Out:
# (100, 4097)
# (100, 4097)
# (100, 4097)
# (100, 4097)
# (100, 4097)

# %%
import pandas as pd
df_a = pd.DataFrame(data = A_signals)
df_b = pd.DataFrame(data = B_signals)
df_c = pd.DataFrame(data = C_signals)
df_d = pd.DataFrame(data = D_signals)
df_normal = pd.concat([df_a, df_b, df_c, df_d])
df_normal['Label'] = 0

# %%
df_normal
# Out:
#        0     1     2     3      4  ...   4093   4094   4095  4096  Label
# 0   -2.0  -8.0 -27.0 -43.0  -39.0  ...   43.0   21.0   17.0 -16.0      0
# 1   31.0  25.0  17.0   7.0    4.0  ...   18.0   23.0   28.0  65.0      0
# 2  -56.0 -50.0 -64.0 -91.0 -135.0  ... -180.0 -173.0 -162.0 -82.0      0
# 3  -45.0 -62.0 -76.0 -98.0 -108.0  ...    9.0  -24.0  -56.0  49.0      0
# 4   37.0  50.0  58.0  58.0   58.0  ...  -55.0  -54.0  -56.0 -41.0      0
# ..   ...   ...   ...   ...    ...  ...    ...    ...    ...   ...    ...
# 95  36.0  40.0  40.0  39.0   42.0  ...   -1.0    1.0    3.0 -10.0      0
# 96  39.0  41.0  41.0  42.0   43.0  ...   58.0   57.0   60.0  -1.0      0
# 97  27.0  29.0  31.0  30.0   24.0  ...   88.0   72.0   58.0 -33.0      0
# 98   0.0   8.0   8.0   2.0    1.0  ...  -76.0  -33.0    0.0  -5.0      0
# 99  -7.0 -12.0 -14.0 -21.0  -31.0  ...    7.0   -1.0  -10.0 -35.0      0
#
# [400 rows x 4098 columns]

# %%
df_e = pd.DataFrame(data = E_signals)
df_e['Label'] = 1
df = pd.concat([df_normal, df_e])
df
# Out:
#         0      1      2       3      4  ...   4093   4094   4095   4096  Label
# 0    -2.0   -8.0  -27.0   -43.0  -39.0  ...   43.0   21.0   17.0  -16.0      0
# 1    31.0   25.0   17.0     7.0    4.0  ...   18.0   23.0   28.0   65.0      0
# 2   -56.0  -50.0  -64.0   -91.0 -135.0  ... -180.0 -173.0 -162.0  -82.0      0
# 3   -45.0  -62.0  -76.0   -98.0 -108.0  ...    9.0  -24.0  -56.0   49.0      0
# 4    37.0   50.0   58.0    58.0   58.0  ...  -55.0  -54.0  -56.0  -41.0      0
# ..    ...    ...    ...     ...    ...  ...    ...    ...    ...    ...    ...
# 95  -71.0  -83.0  -95.0   -88.0  -48.0  ...  105.0  100.0   94.0   59.0      1
# 96   98.0   88.0   76.0    59.0   40.0  ...  250.0  244.0  184.0   70.0      1
# 97  249.0  218.0  176.0   137.0   88.0  ...  373.0  367.0  299.0   26.0      1
# 98 -459.0 -778.0 -981.0 -1048.0 -734.0  ...   -3.0   -8.0  -11.0  949.0      1
# 99  530.0  523.0  424.0   285.0  157.0  ...  307.0  327.0  285.0 -925.0      1
#
# [500 rows x 4098 columns]

# %%
df.to_csv('eeg_signals.csv')
